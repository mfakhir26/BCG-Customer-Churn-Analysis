# %% [markdown]
# # Import the libraries first

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # import the datasets

# %%
 client_df = pd.read_csv('client_data.csv')

# %%
price_df = pd.read_csv('price_data.csv')

# %% [markdown]
# # look at the datasets

# %%
client_df.head(5)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %% [markdown]
# In client dataset, some variables are numeric and some are categorical variables which we might need to transform for modeling later.

# %%
price_df.head(5)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
# 3  038af19179925da21a25619c5a24b745  2015-04-01            0.149626
# 4  038af19179925da21a25619c5a24b745  2015-05-01            0.149626
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
# 3             0.0                 0.0           44.266931             0.0
# 4             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0
# ...

# %% [markdown]
# Price dataset is purely numeric and we can there are lot of zeros in dataset.

# %% [markdown]
# # Data types

# %%
client_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %% [markdown]
# By looking at the above inormation we can say that there are no missing values and there are 14,606 rows in our dataset and there are 11 columns
# whose data type is 'float' and 7 columns are in datatype 'integer' and 8 columns have datatype 'object' meaning that they are non-numeric.

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %% [markdown]
# By looking the inforamtion above, there are only 8 columns in the price dataset and there is no null values and we have 6 columns which have 'float' datatype and 2 columns which have 'object' datatype.

# %% [markdown]
# We can see that Datetime variables are not in date format so we might need to transform these datatypes in date format.

# %% [markdown]
# # Descriptive Statistics

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %% [markdown]
# Decribe method tells us a lot of information about the dataset and we can see that client data is highly skewed data as exhibited by the percentile values.

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %% [markdown]
# Price dataset looks good.
# ___

# %% [markdown]
# # Correlation Matrix

# %%
price_df.corr(numeric_only = True)
# Out:
#                     price_off_peak_var  price_peak_var  price_mid_peak_var  \
# price_off_peak_var            1.000000       -0.328580           -0.594872
# price_peak_var               -0.328580        1.000000            0.821353
# price_mid_peak_var           -0.594872        0.821353            1.000000
# price_off_peak_fix            0.417097       -0.098627           -0.137848
# price_peak_fix               -0.630018        0.796097            0.973960
# price_mid_peak_fix           -0.572229        0.807759            0.979717
#
#                     price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# price_off_peak_var            0.417097       -0.630018           -0.572229
# price_peak_var               -0.098627        0.796097            0.807759
# price_mid_peak_var           -0.137848        0.973960            0.979717
# price_off_peak_fix            1.000000       -0.000428           -0.252661
# ...

# %% [markdown]
# From the above correlation matrix of the dataset 'Price' we can see that there are relationships between the numeric variables of this dataset which might be helpful in further statistical analysis like regression.

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns

# %%
sns.boxplot(price_df[['price_off_peak_var', 'price_peak_var', 'price_mid_peak_var']])
# Out:
# <Axes: >

# %%
sns.boxplot(price_df[['price_off_peak_fix', 'price_peak_fix', 'price_mid_peak_fix']])
# Out:
# <Axes: >

# %% [markdown]
# Since we can see that from above boxplots, variables named 'price_off_peak_var' and 'price_off_peak_fix' have so many outliers while the other variables do not have any outliers, so these outliers might influence statistical analysis if we work on these two columns so we can either remove these outliers or replace the outliers with the exterme values. We will see ahead if we need to remove these outliers otherwise we will not remove them.
# ___

# %% [markdown]
# **Data Distributions**
# ___

# %%
sns.displot(price_df['price_off_peak_var'], kde = True, bins= 35)

# %%
sns.displot(price_df['price_peak_var'], kde = True, bins= 20)

# %%
sns.displot(price_df['price_mid_peak_var'], kde = True, bins= 15)

# %% [markdown]
# By above distribution plots which are made by using seaborn library we can check the distribution of the variables of the dataset. Since, we only checked the distributions of three variables and the distributions of other variables can also be checked by using the same commands. The distribution of variables 'price_peak_var' and 'price_mid_peak_var' seems postive-skewed and by looking at the plots of these two varaibles we can say that the very tall bar near 0 indicates that the portion of the data is exactly or very close to zero. While the plot of variable 'pirce-off_peak_var' suggests that the large portion of data is near 0.15.

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:
        
        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
churn_percentage
# Out:
#        Companies
# churn
# 0      90.284814
# 1       9.715186

# %% [markdown]
# so about 9.71% of the companies have churnned. (This sounds about right)

# %%
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %%
channel = client_df[['id', 'channel_sales', 'churn']]
channel = channel.groupby([channel['channel_sales'], channel['churn']])['id'].count().unstack(level=1).fillna(0)
channel_churn = (channel.div(channel.sum(axis=1), axis=0) * 100).sort_values(by=[1], ascending=False)

# %%
plot_stacked_bars(channel_churn, 'Sales channel', rot_=30)

# %% [markdown]
# so the churning customers are distributed over 5 different channels and the value of MISSING has a churn rate of 7.6%.

# %% [markdown]
# **Consumption**
#
# Let's see the distribution of the consumption of the past 12 months and last month. We will use histograms to check the distributions
# ___

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

# %%
consumption.head(3)
# Out:
#                                  id  cons_12m  cons_gas_12m  cons_last_month  \
# 0  24011ae4ebbe3035111d65fa7c15bc57         0         54946                0
# 1  d29c2c54acc38ff3c0614d0a653813dd      4660             0                0
# 2  764c75f661154dac3a6c254cd082ea7d       544             0                0
#
#    imp_cons has_gas  churn
# 0       0.0       t      1
# 1       0.0       f      0
# 2       0.0       f      0

# %%
plt.hist(consumption['cons_12m'])
plt.xlabel('cons_12m')
plt.ylabel('Frequency')
plt.title('Distribution of cons_12m')
plt.show()

# %%
plt.hist(consumption['cons_gas_12m'])
plt.xlabel('cons_gas_12m')
plt.ylabel('Frequency')
plt.title('Distribution of cons_gas_12m')
plt.show()

# %%
plt.hist(consumption['cons_last_month'])
plt.xlabel('cons_last_month')
plt.ylabel('Frequency')
plt.title('Distribution of cons_last_month')
plt.show()

# %%
plt.hist(consumption['imp_cons'])
plt.xlabel('imp_cons')
plt.ylabel('Frequency')
plt.title('Distribution of imp_cons')
plt.show()

# %% [markdown]
# So from the above histograms, the distribution of the consumption data is positive-skewed. Now we will check if there are any outliers in the consumption data as we did previously for the price data, by making boxplots.
# ___

# %%
fig, axs = plt.subplots(nrows = 4, ncols= 1, figsize = (17,25))
sns.boxplot(consumption['cons_12m'], ax = axs[0])
sns.boxplot(consumption['cons_gas_12m'], ax = axs[1])
sns.boxplot(consumption['cons_last_month'], ax = axs[2])
sns.boxplot(consumption['imp_cons'], ax = axs[3])
# Out:
# <Axes: ylabel='imp_cons'>

# %% [markdown]
# There are so many outliers that we can see in the above boxplots so we will deal with these outliers later because these outliers can influence the statistical analysis so we need to handle these outliers.

# %% [markdown]
# ### **Forecast**

# %%
forecast = client_df[
    ["id", "forecast_cons_12m",
    "forecast_cons_year","forecast_discount_energy","forecast_meter_rent_12m",
    "forecast_price_energy_off_peak","forecast_price_energy_peak",
    "forecast_price_pow_off_peak","churn"
    ]
]

# %%
forecast.head(3)
# Out:
#                                  id  forecast_cons_12m  forecast_cons_year  \
# 0  24011ae4ebbe3035111d65fa7c15bc57               0.00                   0
# 1  d29c2c54acc38ff3c0614d0a653813dd             189.95                   0
# 2  764c75f661154dac3a6c254cd082ea7d              47.96                   0
#
#    forecast_discount_energy  forecast_meter_rent_12m  \
# 0                       0.0                     1.78
# 1                       0.0                    16.27
# 2                       0.0                    38.72
#
#    forecast_price_energy_off_peak  forecast_price_energy_peak  \
# 0                        0.114481                    0.098142
# 1                        0.145711                    0.000000
# 2                        0.165794                    0.087899
#
#    forecast_price_pow_off_peak  churn
# 0                    40.606701      1
# 1                    44.311378      0
# 2                    44.311378      0

# %%
fig, axs = plt.subplots(nrows = 7, figsize = (15,30))

axs[0].hist(forecast['forecast_cons_12m'])
axs[1].hist(forecast['forecast_cons_year'])
axs[2].hist(forecast['forecast_discount_energy'])
axs[3].hist(forecast['forecast_meter_rent_12m'])
axs[4].hist(forecast['forecast_price_energy_off_peak'])
axs[5].hist(forecast['forecast_price_energy_peak'])
axs[6].hist(forecast['forecast_price_pow_off_peak'])
plt.show()
